# %%
import pickle
import matplotlib.pyplot as plt

with open('data/names.pkl', 'rb') as f: LABELS = pickle.load(f)
with open('data/face_data.pkl', 'rb') as f: FACES = pickle.load(f)

# Display the first image
plt.imshow(FACES[1].reshape(50,50, -1))  # Assuming the image is grayscale, adjust the cmap if it's RGB
plt.title(f'Label: {LABELS[1]}')
plt.show()
